# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mayargaber555/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ##  My Lane
#
# I chose the Content Refresh lane because I want to learn how machine learning can identify web pages that need to be refreshed. This can help SEO teams improve website performance and make better decisions.
#
# As an Electrical and Communications Engineering graduate, I am interested in how machine learning can analyze data and support decision-making. This project gives me the opportunity to apply machine learning to a real-world dataset.

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
# !ls
# Out:
# sample_data

# %%
# !find . -name "*.csv"
# Out:
# ./sample_data/california_housing_train.csv
# ./sample_data/california_housing_test.csv
# ./sample_data/mnist_train_small.csv
# ./sample_data/mnist_test.csv

# %%
# !git clone https://github.com/mayargaber555/flyrank-ml-internship.git
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.

# %%
# %cd flyrank-ml-internship
# Out:
# /content/flyrank-ml-internship

# %%
# !pwd
# !ls
# Out:
# /content/flyrank-ml-internship
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(df.head())
print(df.shape)
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
# !ls
# Out:
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %%
# %cd flyrank-ml-internship
# Out:
# [Errno 2] No such file or directory: 'flyrank-ml-internship'
# /content/flyrank-ml-internship

# %% [markdown]
# ## ### Decision, Action, and Cost of a Wrong Call
#
# The goal is to decide which web pages should be refreshed first.
#
# The SEO team will use the recommendations to prioritize content updates.
#
# A wrong recommendation may waste time and resources by refreshing pages that do not need updates while missing pages that actually require attention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The dataset contains 30,000 rows and 44 features. It includes useful SEO metrics such as CTR, search volume, impressions, and content age. These data provide enough information to analyze page performance and support machine learning models for content refresh decisions.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Average CTR:", round(df["ctr"].mean(), 4))
# Out:
# Rows: 30000
# Columns: 44
# Average CTR: 0.5107

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project can identify patterns in the data and provide decision support for content refresh. It can help prioritize which web pages may need updates based on the available data.
#
# However, it cannot prove why a page's performance changes or predict Google's ranking algorithm. The results should be treated as observations and recommendations, not as causal proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ✅] Every section above is filled — markdown thinking AND the code that backs it
# - [✅ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✅ ] No client names, URLs, or private queries anywhere
# - [✅ ] My claims use careful words: observed, measured, directional, decision-support
# - [✅ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
